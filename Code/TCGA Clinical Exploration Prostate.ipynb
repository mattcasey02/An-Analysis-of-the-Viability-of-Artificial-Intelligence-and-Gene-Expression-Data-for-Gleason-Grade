# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
followUp = pd.read_csv('../Data/nationwidechildrens.org_clinical_follow_up_v1.0_prad.txt',delimiter='\t')
NTE = pd.read_csv('../Data/nationwidechildrens.org_clinical_nte_prad.txt' ,delimiter='\t')
OMF = pd.read_csv('../Data/nationwidechildrens.org_clinical_omf_v4.0_prad.txt' ,delimiter='\t')
Patient = pd.read_csv('../Data/nationwidechildrens.org_clinical_patient_prad.txt' ,delimiter='\t')
Radiation = pd.read_csv('../Data/nationwidechildrens.org_clinical_radiation_prad.txt' ,delimiter='\t')
Drug = pd.read_csv('../Data/nationwidechildrens.org_clinical_drug_prad.txt', delimiter='\t')

# %%
followUp
# Out:
#                          bcr_patient_uuid  bcr_patient_barcode  \
# 0                        bcr_patient_uuid  bcr_patient_barcode
# 1                                 CDE_ID:       CDE_ID:2673794
# 2    49197847-CC83-4CE1-8397-D09CEA4C4928         TCGA-2A-A8VL
# 3    91C0D161-2B59-4B7A-8C19-6D26DEA31849         TCGA-2A-A8VO
# 4    931B549F-B9F2-4E8D-83ED-FF663671883C         TCGA-2A-A8VT
# 5    75A7AFB5-66D5-47E3-8A8A-3E3A1E749A96         TCGA-2A-A8VV
# 6    942F1788-D977-4AC0-A177-659F9D4CD077         TCGA-2A-A8VX
# 7    F5319FD5-BEAE-4CA8-8F42-45FCA5E6A2D2         TCGA-2A-A8W1
# 8    5A790086-4887-4D2B-9C28-0FDD5DD1F1FB         TCGA-2A-A8W3
# 9    490E84ED-3C02-4593-990E-ADE5C109DF44         TCGA-2A-AAYF
# 10   8C0D361F-EAAB-4768-90F2-B7A610E2BBB1         TCGA-2A-AAYO
# 11   AA1A3A43-2F9C-456C-BA74-81C29B9801CB         TCGA-2A-AAYU
# 12   5828401b-0901-4a73-9d0c-1e85d3431475         TCGA-CH-5738
# 13   79601d90-b198-4b94-b60f-4cff329c7a10         TCGA-CH-5739
# ...

# %%
NTE
# Out:
#                          bcr_patient_uuid  bcr_patient_barcode  \
# 0                        bcr_patient_uuid  bcr_patient_barcode
# 1                                 CDE_ID:       CDE_ID:2673794
# 2    5A790086-4887-4D2B-9C28-0FDD5DD1F1FB         TCGA-2A-A8W3
# 3    5e2ff1e6-87bc-4b91-a959-f0f553af4e27         TCGA-EJ-7318
# 4    df4a7caa-6289-4157-8cb4-6ce8784e7506         TCGA-EJ-8469
# 5    ab378ad0-1881-403f-9e85-d6f97e7b7c81         TCGA-EJ-8472
# 6    08F11BDD-D665-45AB-B1A2-5485D91922C2         TCGA-EJ-A46F
# 7    8631BB5E-6D08-4C20-A85E-CB84F5DAC290         TCGA-EJ-A65F
# 8    4EF24CCA-976B-4C2F-8810-4339967DA570         TCGA-EJ-A6RA
# 9    C8FAB4A7-FD7E-4D5E-A330-18C7E148B9D0         TCGA-EJ-A7NN
# 10   00F0F7DD-71DE-4E4F-B4B5-DF860324F2E8         TCGA-EJ-A8FP
# 11   9044098B-415D-4893-A682-3636F6B2B2DB         TCGA-EJ-A8FS
# 12   F97FED28-FDF3-4C82-8B6D-1015848B80DC         TCGA-FC-A6HD
# 13   d39d1a49-fcc0-4f2c-9338-df904e7f6a09         TCGA-G9-6339
# ...

# %%
OMF
# Out:
#                         bcr_patient_uuid  bcr_patient_barcode  \
# 0                       bcr_patient_uuid  bcr_patient_barcode
# 1                                CDE_ID:       CDE_ID:2673794
# 2   928c48a0-68ee-4e28-ae83-9832e52850ca         TCGA-CH-5753
# 3   18e79a01-07a2-4cd5-b700-71d41724e041         TCGA-CH-5763
# 4   ed73f136-42e8-4100-b432-d10370d07e8b         TCGA-CH-5764
# 5   ecf9f8be-7830-4626-8617-694c68ef4074         TCGA-CH-5772
# 6   2b5ef82d-e137-43f6-bfef-b202f20ee187         TCGA-CH-5790
# 7   829bed0c-c40d-44fd-aee8-6c7589db60f9         TCGA-CH-5791
# 8   5a92ec4c-36ee-4588-aca2-e3303f29c7ad         TCGA-EJ-5542
# 9   9519be01-d78d-462c-8a95-34149538afeb         TCGA-EJ-7123
# 10  00dda860-53c3-4ab2-8294-73e291adf9d2         TCGA-EJ-7312
# 11  45a04209-8fac-4181-bba3-1437c8fd7f09         TCGA-EJ-7325
# 12  4fe004e5-49f9-4336-a690-6ebad512c813         TCGA-EJ-7791
# 13  1170F449-DFB5-417A-A89B-B2229A2785DB         TCGA-EJ-A46B
# ...

# %%
Patient
# Out:
#                          bcr_patient_uuid  bcr_patient_barcode  \
# 0                        bcr_patient_uuid  bcr_patient_barcode
# 1                                 CDE_ID:       CDE_ID:2673794
# 2    49197847-CC83-4CE1-8397-D09CEA4C4928         TCGA-2A-A8VL
# 3    91C0D161-2B59-4B7A-8C19-6D26DEA31849         TCGA-2A-A8VO
# 4    931B549F-B9F2-4E8D-83ED-FF663671883C         TCGA-2A-A8VT
# 5    75A7AFB5-66D5-47E3-8A8A-3E3A1E749A96         TCGA-2A-A8VV
# 6    942F1788-D977-4AC0-A177-659F9D4CD077         TCGA-2A-A8VX
# 7    F5319FD5-BEAE-4CA8-8F42-45FCA5E6A2D2         TCGA-2A-A8W1
# 8    5A790086-4887-4D2B-9C28-0FDD5DD1F1FB         TCGA-2A-A8W3
# 9    490E84ED-3C02-4593-990E-ADE5C109DF44         TCGA-2A-AAYF
# 10   8C0D361F-EAAB-4768-90F2-B7A610E2BBB1         TCGA-2A-AAYO
# 11   AA1A3A43-2F9C-456C-BA74-81C29B9801CB         TCGA-2A-AAYU
# 12   47ABCD03-C6FF-4777-AC26-F880474092FF         TCGA-4L-AA1F
# 13   4f9f1fce-d96e-407b-a873-56129985aece         TCGA-CH-5737
# ...

# %%
Radiation
# Out:
#                         bcr_patient_uuid  bcr_patient_barcode  \
# 0                       bcr_patient_uuid  bcr_patient_barcode
# 1                                CDE_ID:       CDE_ID:2673794
# 2   931B549F-B9F2-4E8D-83ED-FF663671883C         TCGA-2A-A8VT
# 3   4048c139-1329-4e6a-8d2f-c0aa104a68ee         TCGA-EJ-5524
# 4   8631BB5E-6D08-4C20-A85E-CB84F5DAC290         TCGA-EJ-A65F
# 5   30F623A3-DAE7-41DA-AB10-8786D094209E         TCGA-FC-A4JI
# 6   F7238E82-A394-4A7C-8514-6241D0AA17E3         TCGA-FC-A5OB
# 7   F7238E82-A394-4A7C-8514-6241D0AA17E3         TCGA-FC-A5OB
# 8   d39d1a49-fcc0-4f2c-9338-df904e7f6a09         TCGA-G9-6339
# 9   f59b9c65-46e8-4cc3-aa71-8844f6c2273c         TCGA-G9-6351
# 10  b8fbfe87-e92c-4d54-a620-17b2dcde6d53         TCGA-G9-6498
# 11  084AC674-F4CF-4A4A-A6A2-687C05C272EA         TCGA-G9-A9S0
# 12  084AC674-F4CF-4A4A-A6A2-687C05C272EA         TCGA-G9-A9S0
# 13  084AC674-F4CF-4A4A-A6A2-687C05C272EA         TCGA-G9-A9S0
# ...

# %%
Drug
# Out:
#                          bcr_patient_uuid  bcr_patient_barcode  \
# 0                        bcr_patient_uuid  bcr_patient_barcode
# 1                                 CDE_ID:       CDE_ID:2673794
# 2    931B549F-B9F2-4E8D-83ED-FF663671883C         TCGA-2A-A8VT
# 3    47ABCD03-C6FF-4777-AC26-F880474092FF         TCGA-4L-AA1F
# 4    b3bf57d4-e31a-4740-b438-fa826fb79550         TCGA-CH-5741
# 5    721e76d0-4b1d-4e78-adb8-1344b8030062         TCGA-CH-5751
# 6    721e76d0-4b1d-4e78-adb8-1344b8030062         TCGA-CH-5751
# 7    721e76d0-4b1d-4e78-adb8-1344b8030062         TCGA-CH-5751
# 8    d8f56d75-51ab-4a86-a502-c86e1dcd1eff         TCGA-CH-5752
# 9    c039014f-821c-43d6-9d3c-914f9c8d98fa         TCGA-CH-5788
# 10   c039014f-821c-43d6-9d3c-914f9c8d98fa         TCGA-CH-5788
# 11   30F623A3-DAE7-41DA-AB10-8786D094209E         TCGA-FC-A4JI
# 12   F7238E82-A394-4A7C-8514-6241D0AA17E3         TCGA-FC-A5OB
# 13   cf70909e-5143-47ae-b8ca-c3ae6ace7be2         TCGA-G9-7521
# ...
