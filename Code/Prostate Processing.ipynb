# %%
import pandas as pd

# %%
TCGAHealthy = pd.read_csv('../Data/pradrsemfpkmtcga.txt',delimiter='\t')
TCGACancer = pd.read_csv('../Data/pradrsemfpkmtcgat.txt',delimiter='\t')
GTEX = pd.read_csv('../Data/prostatersemfpkmgtex.txt',delimiter='\t')

# %% [markdown]
# GTEX Naming Scheme:
#
#
# The sample ID for an RNA-Seq or genotype sample is made up of the following 3 components separated by a dash, as exemplified with the example "GTEX-14753-1626-SM-5NQ9L":
#
#
# "GTEX-YYYYY" (e.g. GTEX-14753) represents the GTEx donor ID. This ID should be used to link between the various RNA-Seq and genotype samples that come from the same donor.
#
#
# "YYYY" (e.g., "1626") mostly refers to the tissue site, BUT we do not recommend using it for tissue site designation. Sometimes sample mix-ups occur, and will be corrected however this part of the ID will not change when that happens. The accurate tissue site designation for all samples can be obtained from the "Tissue Site Detail field" (encoded as "SMTSD") in the Sample Attributes file [Datasets->Download->GTEx_Data_V6_Annotations_SampleAttributesDS.txt].
#
#
# "SM-YYYYY" (e.g., SM-5NQ9L) is the RNA or DNA aliquot ID used for sequencing.
#
#
# 'Y' stands for any number or capital letter.

# %% [markdown]
# TCGA Naming Scheme:
# ![image.png](attachment:image.png)

# %%
TCGAHealthy.replace('?','UNK',inplace=True)
TCGACancer.replace('?','UNK',inplace=True)
GTEX.replace('?','UNK',inplace=True)

# %%
TCGAHealthy.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-EJ-7789-11A-01R-2118-07  \
# 0        CUL5            8065                        307.69
# 1        REV1           51455                        503.95
# 2      ZNF428          126299                       1008.90
# 3      CX3CR1            1524                         85.82
# 4        FAXC           84553                        239.52
#
#    TCGA-EJ-7327-11A-01R-2118-07  TCGA-EJ-7794-11A-01R-2118-07  \
# 0                        314.17                        353.59
# 1                        423.61                        698.41
# 2                        995.00                        967.76
# 3                        120.94                        221.86
# 4                        248.00                        253.23
#
#    TCGA-HC-7745-11A-01R-2118-07  TCGA-CH-5761-11A-01R-1580-07  \
# 0                        215.77                        251.48
# 1                        490.14                        536.45
# ...

# %%
TCGACancer.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-VN-A88P-01A-11R-A352-07  \
# 0        CUL5            8065                        218.79
# 1        REV1           51455                        420.68
# 2      ZNF428          126299                       1135.20
# 3      CX3CR1            1524                          5.36
# 4        FAXC           84553                        100.13
#
#    TCGA-CH-5739-01A-11R-1580-07  TCGA-V1-A9OH-01A-11R-A41O-07  \
# 0                        329.84                        205.50
# 1                        500.46                        476.71
# 2                        599.49                       1467.37
# 3                         98.04                         35.25
# 4                        226.54                        191.67
#
#    TCGA-EJ-7331-01A-11R-2118-07  TCGA-XK-AAIV-01A-11R-A41O-07  \
# 0                        392.44                        223.41
# 1                        536.45                        438.59
# ...

# %%
GTEX.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  GTEX-111CU-1526-SM-5N9FS  \
# 0        CUL5            8065                    291.04
# 1        REV1           51455                    429.54
# 2      ZNF428          126299                    995.00
# 3      CX3CR1            1524                     43.94
# 4        FAXC           84553                    320.80
#
#    GTEX-U8XE-2526-SM-4E3IT  GTEX-NPJ8-2426-SM-3MJHL  GTEX-132QS-1126-SM-5P9GC  \
# 0                   170.25                   131.51                    275.28
# 1                   521.76                   309.83                    536.45
# 2                   665.29                   796.86                   1051.79
# 3                    39.79                    10.16                     73.03
# 4                   262.20                   185.11                    358.54
#
#    GTEX-WFG7-1826-SM-3GIL1  GTEX-12BJ1-1226-SM-5LUAE  \
# 0                   373.81                    400.71
# ...

# %%
TCGAHealthy['GeneID'] = TCGAHealthy['Hugo_Symbol'] +'-'+ TCGAHealthy['Entrez_Gene_Id'].astype(str)
TCGACancer['GeneID'] = TCGACancer['Hugo_Symbol'] +'-'+ TCGACancer['Entrez_Gene_Id'].astype(str)
GTEX['GeneID'] = GTEX['Hugo_Symbol'] +'-'+ GTEX['Entrez_Gene_Id'].astype(str)

# %%
TCGAHealthy.drop(['Hugo_Symbol','Entrez_Gene_Id'],axis=1,inplace=True)
TCGACancer.drop(['Hugo_Symbol','Entrez_Gene_Id'],axis=1,inplace=True)
GTEX.drop(['Hugo_Symbol','Entrez_Gene_Id'],axis=1,inplace=True)

# %%
TCGAHealthy.set_index('GeneID',inplace=True)
TCGACancer.set_index('GeneID',inplace=True)
GTEX.set_index('GeneID',inplace=True)

# %%
TCGAHealthy.head()
# Out:
#                TCGA-EJ-7789-11A-01R-2118-07  TCGA-EJ-7327-11A-01R-2118-07  \
# GeneID
# CUL5-8065                            307.69                        314.17
# REV1-51455                           503.95                        423.61
# ZNF428-126299                       1008.90                        995.00
# CX3CR1-1524                           85.82                        120.94
# FAXC-84553                           239.52                        248.00
#
#                TCGA-EJ-7794-11A-01R-2118-07  TCGA-HC-7745-11A-01R-2118-07  \
# GeneID
# CUL5-8065                            353.59                        215.77
# REV1-51455                           698.41                        490.14
# ZNF428-126299                        967.76                        928.30
# CX3CR1-1524                          221.86                         98.04
# FAXC-84553                           253.23                        454.09
#
# ...

# %%
TCGACancer.head()
# Out:
#                TCGA-VN-A88P-01A-11R-A352-07  TCGA-CH-5739-01A-11R-1580-07  \
# GeneID
# CUL5-8065                            218.79                        329.84
# REV1-51455                           420.68                        500.46
# ZNF428-126299                       1135.20                        599.49
# CX3CR1-1524                            5.36                         98.04
# FAXC-84553                           100.13                        226.54
#
#                TCGA-V1-A9OH-01A-11R-A41O-07  TCGA-EJ-7331-01A-11R-2118-07  \
# GeneID
# CUL5-8065                            205.50                        392.44
# REV1-51455                           476.71                        536.45
# ZNF428-126299                       1467.37                        775.05
# CX3CR1-1524                           35.25                         33.54
# FAXC-84553                           191.67                        194.36
#
# ...

# %%
GTEX.head()
# Out:
#                GTEX-111CU-1526-SM-5N9FS  GTEX-U8XE-2526-SM-4E3IT  \
# GeneID
# CUL5-8065                        291.04                   170.25
# REV1-51455                       429.54                   521.76
# ZNF428-126299                    995.00                   665.29
# CX3CR1-1524                       43.94                    39.79
# FAXC-84553                       320.80                   262.20
#
#                GTEX-NPJ8-2426-SM-3MJHL  GTEX-132QS-1126-SM-5P9GC  \
# GeneID
# CUL5-8065                       131.51                    275.28
# REV1-51455                      309.83                    536.45
# ZNF428-126299                   796.86                   1051.79
# CX3CR1-1524                      10.16                     73.03
# FAXC-84553                      185.11                    358.54
#
#                GTEX-WFG7-1826-SM-3GIL1  GTEX-12BJ1-1226-SM-5LUAE  \
# GeneID
# CUL5-8065                       373.81                    400.71
# ...

# %%
TCGAHealthy = TCGAHealthy.T
TCGACancer = TCGACancer.T
GTEX = GTEX.T

# %%
# Used to make sure same length name and all same same diagnosis
'''
TCGAHealthy['GeneIdName'] = TCGAHealthy.index
TCGAHealthy['GeneIdLen'] = TCGAHealthy['GeneIdName'].apply(lambda x: len(x))
TCGAHealthy['GeneIdLen'].value_counts()
TCGAHealthy['TargetRaw'] = TCGAHealthy['GeneIdName'].apply(lambda x:int(x[13:15]))
TCGAHealthy['TargetRaw'].value_counts()

TCGACancer['GeneIdName'] = TCGACancer.index
TCGACancer['GeneIdLen'] = TCGACancer['GeneIdName'].apply(lambda x: len(x))
TCGACancer['GeneIdLen'].value_counts()
TCGACancer['TargetRaw'] = TCGACancer['GeneIdName'].apply(lambda x:int(x[13:15]))
TCGACancer['TargetRaw'].value_counts()
'''
# Out:
# "\nTCGAHealthy['GeneIdName'] = TCGAHealthy.index\nTCGAHealthy['GeneIdLen'] = TCGAHealthy['GeneIdName'].apply(lambda x: len(x))\nTCGAHealthy['GeneIdLen'].value_counts()\nTCGAHealthy['TargetRaw'] = TCGAHealthy['GeneIdName'].apply(lambda x:int(x[13:15]))\nTCGAHealthy['TargetRaw'].value_counts()\n\nTCGACancer['GeneIdName'] = TCGACancer.index\nTCGACancer['GeneIdLen'] = TCGACancer['GeneIdName'].apply(lambda x: len(x))\nTCGACancer['GeneIdLen'].value_counts()\nTCGACancer['TargetRaw'] = TCGACancer['GeneIdName'].apply(lambda x:int(x[13:15]))\nTCGACancer['TargetRaw'].value_counts()\n"

# %%
# 1 Is Cancer
# 0 Is Healthy
TCGAHealthy['Target'] = 0
TCGACancer['Target'] = 1
GTEX['Target'] = 0

# %%
TCGAHealthy.head()
# Out:
# GeneID                        CUL5-8065  REV1-51455  ZNF428-126299  \
# TCGA-EJ-7789-11A-01R-2118-07     307.69      503.95        1008.90
# TCGA-EJ-7327-11A-01R-2118-07     314.17      423.61         995.00
# TCGA-EJ-7794-11A-01R-2118-07     353.59      698.41         967.76
# TCGA-HC-7745-11A-01R-2118-07     215.77      490.14         928.30
# TCGA-CH-5761-11A-01R-1580-07     251.48      536.45        1359.57
#
# GeneID                        CX3CR1-1524  FAXC-84553  PKP2-5318  BNIP2-663  \
# TCGA-EJ-7789-11A-01R-2118-07        85.82      239.52     239.52     674.59
# TCGA-EJ-7327-11A-01R-2118-07       120.94      248.00     334.46     503.95
# TCGA-EJ-7794-11A-01R-2118-07       221.86      253.23     361.04    1359.57
# TCGA-HC-7745-11A-01R-2118-07        98.04      454.09     236.21     909.17
# TCGA-CH-5761-11A-01R-1580-07       136.19      237.86     356.05     764.36
#
# GeneID                        HOXB7-3217  GRIN3A-116443  FCRL5-83416   ...    \
# ...

# %%
TCGACancer.head()
# Out:
# GeneID                        CUL5-8065  REV1-51455  ZNF428-126299  \
# TCGA-VN-A88P-01A-11R-A352-07     218.79      420.68        1135.20
# TCGA-CH-5739-01A-11R-1580-07     329.84      500.46         599.49
# TCGA-V1-A9OH-01A-11R-A41O-07     205.50      476.71        1467.37
# TCGA-EJ-7331-01A-11R-2118-07     392.44      536.45         775.05
# TCGA-XK-AAIV-01A-11R-A41O-07     223.41      438.59        1104.13
#
# GeneID                        CX3CR1-1524  FAXC-84553  PKP2-5318  BNIP2-663  \
# TCGA-VN-A88P-01A-11R-A352-07         5.36      100.13     214.27     688.78
# TCGA-CH-5739-01A-11R-1580-07        98.04      226.54     379.04     836.53
# TCGA-V1-A9OH-01A-11R-A41O-07        35.25      191.67     242.88     507.46
# TCGA-EJ-7331-01A-11R-2118-07        33.54      194.36     323.03     733.19
# TCGA-XK-AAIV-01A-11R-A41O-07        22.92      198.47     138.10     511.00
#
# GeneID                        HOXB7-3217  GRIN3A-116443  FCRL5-83416   ...    \
# ...

# %%
GTEX.head()
# Out:
# GeneID                    CUL5-8065  REV1-51455  ZNF428-126299  CX3CR1-1524  \
# GTEX-111CU-1526-SM-5N9FS     291.04      429.54         995.00        43.94
# GTEX-U8XE-2526-SM-4E3IT      170.25      521.76         665.29        39.79
# GTEX-NPJ8-2426-SM-3MJHL      131.51      309.83         796.86        10.16
# GTEX-132QS-1126-SM-5P9GC     275.28      536.45        1051.79        73.03
# GTEX-WFG7-1826-SM-3GIL1      373.81      587.13         647.07        65.26
#
# GeneID                    FAXC-84553  PKP2-5318  BNIP2-663  HOXB7-3217  \
# GTEX-111CU-1526-SM-5N9FS      320.80     371.22     780.44      104.42
# GTEX-U8XE-2526-SM-4E3IT       262.20     356.05    1119.56      146.03
# GTEX-NPJ8-2426-SM-3MJHL       185.11      75.64     497.00      249.73
# GTEX-132QS-1126-SM-5P9GC      358.54     429.54    1073.91       29.70
# GTEX-WFG7-1826-SM-3GIL1       361.04     476.71    1051.79       56.28
#
# GeneID                    GRIN3A-116443  FCRL5-83416   ...    GATA6-2627  \
# ...

# %%
import pickle

# %%
TCGAHealthy.to_pickle('../Data/TCGAHealthy.pkl')
TCGACancer.to_pickle('../Data/TCGACancer.pkl')
GTEX.to_pickle('../Data/GTEX.pkl')

# %%
Prostate = TCGAHealthy.append(TCGACancer.append(GTEX))

# %%
Prostate.reset_index(drop = True, inplace = True)

# %%
Prostate.head()
# Out:
# GeneID  CUL5-8065  REV1-51455  ZNF428-126299  CX3CR1-1524  FAXC-84553  \
# 0          307.69      503.95        1008.90        85.82      239.52
# 1          314.17      423.61         995.00       120.94      248.00
# 2          353.59      698.41         967.76       221.86      253.23
# 3          215.77      490.14         928.30        98.04      454.09
# 4          251.48      536.45        1359.57       136.19      237.86
#
# GeneID  PKP2-5318  BNIP2-663  HOXB7-3217  GRIN3A-116443  FCRL5-83416   ...    \
# 0          239.52     674.59      107.38          28.86         9.70   ...
# 1          334.46     503.95       16.51          17.77         0.79   ...
# 2          361.04    1359.57      166.73          15.11        24.46   ...
# 3          236.21     909.17     1331.57          83.45         0.00   ...
# 4          356.05     764.36       23.76           7.94        11.38   ...
#
# GeneID  GATA6-2627  COL28A1-340267  PDK3-5165  MC1R-4157  IFT74-80173  \
# ...

# %%
Prostate = Prostate.sample(frac=1).reset_index(drop=True)

# %%
Prostate
# Out:
# GeneID  CUL5-8065  REV1-51455  ZNF428-126299  CX3CR1-1524  FAXC-84553  \
# 0          205.50      521.76        2119.22        30.12      150.17
# 1          221.86      334.46        1159.07        18.97      229.72
# 2          299.25      358.54        1216.75        11.55      246.28
# 3          236.21      529.06        1540.37        27.84      224.97
# 4          277.20      414.87         836.53        72.52     1015.93
# 5          190.34      353.59         954.43         9.41      329.84
# 6          231.32      511.00         830.75        58.30      155.50
# 7          177.53      525.39        1745.20        30.12      323.03
# 8          177.53      713.11         819.30        32.13      206.94
# 9          297.17      532.74         934.76       161.02      341.51
# 10         214.27      297.17        1359.57        72.01      275.28
# 11         283.05      497.00        1388.16        71.50      217.27
# ...

# %%
Prostate['Target'].value_counts()
# Out:
# 1    426
# 0    154
# Name: Target, dtype: int64

# %% [markdown]
# Prostate has ~3:1 (426:154) Cancerous:Healthy (48 TCGAH, 106 GTEx, 426 TCGAC)

# %%
Prostate.to_pickle('../Data/Prostate.pkl')
