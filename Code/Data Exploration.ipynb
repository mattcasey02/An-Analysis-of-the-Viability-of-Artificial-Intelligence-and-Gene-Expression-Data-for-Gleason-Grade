# %%
import pandas as pd

# %%
TCGAHealthy = pd.read_csv('../Data/pradrsemfpkmtcga.txt',delimiter='\t')

# %%
TCGAHealthy
# Out:
#         Hugo_Symbol  Entrez_Gene_Id  TCGA-EJ-7789-11A-01R-2118-07  \
# 0              CUL5            8065                        307.69
# 1              REV1           51455                        503.95
# 2            ZNF428          126299                       1008.90
# 3            CX3CR1            1524                         85.82
# 4              FAXC           84553                        239.52
# 5              PKP2            5318                        239.52
# 6             BNIP2             663                        674.59
# 7             HOXB7            3217                        107.38
# 8            GRIN3A          116443                         28.86
# 9             FCRL5           83416                          9.70
# 10           GPR150          285601                         15.45
# 11          ADORA2A             135                         52.45
# 12             YBX2           51087                         14.35
# ...

# %%
TCGACancer = pd.read_csv('../Data/pradrsemfpkmtcgat.txt',delimiter='\t')

# %%
TCGACancer
# Out:
#         Hugo_Symbol  Entrez_Gene_Id  TCGA-VN-A88P-01A-11R-A352-07  \
# 0              CUL5            8065                        218.79
# 1              REV1           51455                        420.68
# 2            ZNF428          126299                       1135.20
# 3            CX3CR1            1524                          5.36
# 4              FAXC           84553                        100.13
# 5              PKP2            5318                        214.27
# 6             BNIP2             663                        688.78
# 7             HOXB7            3217                         40.93
# 8            GRIN3A          116443                          5.59
# 9             FCRL5           83416                          2.34
# 10           GPR150          285601                          2.53
# 11          ADORA2A             135                         67.59
# 12             YBX2           51087                          4.35
# ...

# %%
GTEX = pd.read_csv('../Data/prostatersemfpkmgtex.txt',delimiter='\t')

# %%
GTEX
# Out:
#         Hugo_Symbol  Entrez_Gene_Id  GTEX-111CU-1526-SM-5N9FS  \
# 0              CUL5            8065                    291.04
# 1              REV1           51455                    429.54
# 2            ZNF428          126299                    995.00
# 3            CX3CR1            1524                     43.94
# 4              FAXC           84553                    320.80
# 5              PKP2            5318                    371.22
# 6             BNIP2             663                    780.44
# 7             HOXB7            3217                    104.42
# 8            GRIN3A          116443                      6.94
# 9             FCRL5           83416                      1.25
# 10           GPR150          285601                      4.94
# 11          ADORA2A             135                     62.56
# 12             YBX2           51087                     18.16
# 13             CD1B             910                      1.95
# ...

# %%
BRCAHealthy = pd.read_csv('../Data/brcarsemfpkmtcga.txt',delimiter='\t')
BRCACancer = pd.read_csv('../Data/brcarsemfpkmtcgat.txt',delimiter='\t')
GTEXBreast = pd.read_csv('../Data/breastrsemfpkmgtex.txt',delimiter='\t')

# %%
BRCAHealthy
# Out:
#          Hugo_Symbol  Entrez_Gene_Id  TCGA-BH-A1EU-11A-23R-A137-07  \
# 0              KIF1C           10749                       1674.06
# 1             SWAP70           23075                       1088.92
# 2               PAK1            5058                        748.61
# 3           KRTAP9-1          728318                          0.00
# 4            PLEKHM3          389072                        110.43
# 5              MCFD2           90411                       1697.45
# 6              RBM12           10137                        836.53
# 7              KRT86            3892                         28.24
# 8             PSMD12            5718                        785.88
# 9            SLC7A11           23657                         10.96
# 10            BTN3A1           11119                        457.25
# 11             SFTPB            6439                          0.46
# 12             LPIN1           23175                        723.08
# ...

# %%
BRCACancer
# Out:
#          Hugo_Symbol  Entrez_Gene_Id  TCGA-AC-A2BM-01A-11R-A21T-07  \
# 0              KIF1C           10749                        974.50
# 1             SWAP70           23075                        387.02
# 2               PAK1            5058                        748.61
# 3           KRTAP9-1          728318                          0.00
# 4            PLEKHM3          389072                         31.22
# 5              MCFD2           90411                        928.30
# 6              RBM12           10137                       1001.93
# 7              KRT86            3892                          1.01
# 8             PSMD12            5718                        974.50
# 9            SLC7A11           23657                         53.19
# 10            BTN3A1           11119                        320.80
# 11             SFTPB            6439                          1.03
# 12             LPIN1           23175                        251.48
# ...

# %%
GTEXBreast
# Out:
#          Hugo_Symbol  Entrez_Gene_Id  GTEX-WYVS-1726-SM-3NMAY  \
# 0              KIF1C           10749                  1199.98
# 1             SWAP70           23075                   836.53
# 2               PAK1            5058                  1407.55
# 3           KRTAP9-1          728318                     0.00
# 4            PLEKHM3          389072                    78.89
# 5              MCFD2           90411                  1286.18
# 6              RBM12           10137                   890.44
# 7              KRT86            3892                    31.00
# 8             PSMD12            5718                   802.41
# 9            SLC7A11           23657                    36.27
# 10            BTN3A1           11119                  1794.29
# 11             SFTPB            6439                     6.26
# 12             LPIN1           23175                   389.72
# 13            NT5C1A           84618                     0.00
# ...

# %% [markdown]
# Prostate has ~3:1 (426:154) Cancerous:Healthy (48 TCGAH, 106 GTEx, 426 TCGAC)
#
# Breast has ~5:1 (982:199) Cancerous:Healthy (110 TCGAH, 89 GTEx, 982 TCGAC)
